# %%
from util import load_model_summary_dicts, show_model_summary_dict

summary_dicts = load_model_summary_dicts()
summary_dicts = reversed(sorted(summary_dicts, key=lambda x: x["Accuracy"]))

for summary_dict in summary_dicts:
    show_model_summary_dict(summary_dict)
    print("\n\n\n")
# Out:
# BERT Accuracy: 0.77
# BERT Precision: 0.76
# BERT Recall: 0.77
# BERT F1: 0.76
# LLM Accuracy: 0.75
# LLM Precision: 0.75
# LLM Recall: 0.75
# LLM F1: 0.71
# LSTM Accuracy: 0.70
# LSTM Precision: 0.70
# LSTM Recall: 0.70
# LSTM F1: 0.69
# Logistic Regression Accuracy: 0.69
# Logistic Regression Precision: 0.69
# Logistic Regression Recall: 0.69
# Logistic Regression F1: 0.68
# Logistic Regression AUC: 0.87
# Logistic Regression Gini: 0.74
# Naive Bayes Accuracy: 0.63
# Naive Bayes Precision: 0.72
# Naive Bayes Recall: 0.63
# Naive Bayes F1: 0.59
# Naive Bayes AUC: 0.84
# Naive Bayes Gini: 0.68
# Decision Tree Accuracy: 0.53
# Decision Tree Precision: 0.53
# Decision Tree Recall: 0.53
# Decision Tree F1: 0.53
# Decision Tree AUC: 0.66
# Decision Tree Gini: 0.32
